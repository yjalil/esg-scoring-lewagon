# %%
import pandas as pd
from nltk import tokenize
import seaborn as sns

# %%
df = pd.read_csv('../../raw_data/labeled_sentences_merged_imbalanced_12k_extra_classes.csv' )

# %%
df.head(20)
# Out:
#     Unnamed: 0                                           sentence  \
# 0            0  Fallout from the scandal could lead to a lost ...
# 1            1  The damning parliamentary report into the demi...
# 2            2  The BHS scandal has been described by MPs as t...
# 3            3  Dominic Chappell, the businessman who bought B...
# 4            4  The fallout from the scandal could lead to a k...
# 5            5  Around 11,000 jobs are at risk after BHS colla...
# 6            6  Green controlled BHS for 15 years until March ...
# 7            7  Green and other shareholders extracted £586m i...
# 8            8  Pensions\nBHS has been left with a pension def...
# 9            9  Green told MPs that problems facing the pensio...
# 10          10  He added: “We will sort it, we will find a sol...
# 11          11  “His family took out of BHS and Arcadia a fort...
# 12          12  The Pensions Regulator, which could force Gree...
# ...
