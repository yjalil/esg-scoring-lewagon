# %%
from nltk import tokenize
import pandas as pd

# %%
with open('Data/BHS_governance_scandal.txt',encoding='utf8') as f:
    data = f.read()

# %%
# tested in transformers==4.18.0 
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

finbert = AutoModelForSequenceClassification.from_pretrained('Models/topic_model/',num_labels=4)
tokenizer = AutoTokenizer.from_pretrained('Models/topic_tokenizer/')
nlp = pipeline("text-classification", model=finbert, tokenizer=tokenizer)

# %%
finbert_sentiment = AutoModelForSequenceClassification.from_pretrained('Models/sentiment_model/',num_labels=3)
tokenizer_sentiment = AutoTokenizer.from_pretrained('Models/sentiment_tokenizer/')
nlp_sentiment = pipeline("text-classification", model=finbert_sentiment, tokenizer=tokenizer_sentiment)

# %%
finbert_fls = AutoModelForSequenceClassification.from_pretrained('Models/fls_model/',num_labels=3)
tokenizer_fls = AutoTokenizer.from_pretrained('Models/fls_tokenizer/')
nlp_fls = pipeline("text-classification", model=finbert_fls, tokenizer=tokenizer_fls)

# %%
finbert_sub_cat = AutoModelForSequenceClassification.from_pretrained('Models/subESG_model/',num_labels=9)
tokenizer_sub_cat = AutoTokenizer.from_pretrained('Models/subESG_tokenizer/')
nlp_sub_cat = pipeline("text-classification", model=finbert_sub_cat, tokenizer=tokenizer_sub_cat)

# %%
list_all_sentences = tokenize.sent_tokenize(data)
len(list_all_sentences)
# Out:
# 58

# %%
list_all_sentences_short = [sentence for sentence in list_all_sentences if len(sentence)<500]
len(list_all_sentences_short)
# Out:
# 58

# %%
def build_dataset(lst):
    try:
        dataset_lst = []
        for sentence in lst :
            topic_label= nlp(sentence)[0]['label']
            topic_score = nlp(sentence)[0]['score']
            
            sentiment_label = nlp_sentiment(sentence)[0]['label']
            sentiment_score = nlp_sentiment(sentence)[0]['score']
            
            fls_label = nlp_fls(sentence)[0]['label']
            fls_score = nlp_fls(sentence)[0]['score']
            
            sub_cat_label = nlp_sub_cat(sentence)[0]['label']
            sub_cat_score = nlp_sub_cat(sentence)[0]['score']
            
            print(f'{sentence[0:25]} belongs to {topic_label}({topic_score}%) with a sentiment {sentiment_label}({sentiment_score}% =>{sub_cat_label})')
            dataset_lst.append({'sentence':sentence,
                                'topic_label': topic_label,
                                'topic_score': topic_score,
                                'sentiment_label': sentiment_label,
                                'sentiment_score': sentiment_score,
                                'fls_label': fls_label,
                                'fls_score': fls_score,
                                'sub_cat_label': sub_cat_label,
                                'sub_cat_score': sub_cat_score                                
                                })
    except:
        dataset_lst.append({'sentence':sentence,
                                'topic_label': 'error',
                                'topic_score': 0,
                                'sentiment_label': 'error',
                                'sentiment_score': 0,
                                'fls_label': 'error',
                                'fls_score': 0,
                                'sub_cat_label': 'error',
                                'sub_cat_score': 0})
    return dataset_lst

# %%
dataset_lst = build_dataset(list_all_sentences_short)
# Out:
# Fallout from the scandal  belongs to Governance(0.4531234800815582%) with a sentiment Negative(0.9998595714569092% =>Business Ethics & Values)
# The damning parliamentary belongs to Social(0.9786429405212402%) with a sentiment Negative(0.9997097849845886% =>Community Relations)
# The BHS scandal has been  belongs to Environmental(0.9315072298049927%) with a sentiment Negative(0.9592201113700867% =>Pollution & Waste)
# Dominic Chappell, the bus belongs to Social(0.9576088190078735%) with a sentiment Neutral(0.9999719858169556% =>Product Liability)
# The fallout from the scan belongs to Governance(0.40840819478034973%) with a sentiment Negative(0.9984422326087952% =>Business Ethics & Values)
# Around 11,000 jobs are at belongs to Social(0.9828281402587891%) with a sentiment Negative(0.7277733087539673% =>Human Capital)
# Green controlled BHS for  belongs to Social(0.9706413745880127%) with a sentiment Neutral(0.9993252754211426% =>Community Relations)
# Green and other sharehold belongs to Governance(0.6412906050682068%) with a sentiment Neutral(0.9997684359550476% =>Corporate Governance)
# Pensions
# BHS has been lef belongs to None(0.9121007323265076%) with a sentiment Negative(0.8813468217849731% =>Community Relations)
# Green told MPs that probl belongs to Social(0.9684160947799683%) with a sentiment Negative(0.9774302244186401% =>Community Relations)
# He added: “We will sort i belongs to Social(0.9666053056716919%) with a sentiment Negative(0.9999277591705322% =>Corporate Governance)
# “His family took out of B belongs to Social(0.9704207181930542%) with a sentiment Neutral(0.9935076236724854% =>Corporate Governance)
# The Pensions Regulator, w belongs to None(0.7731738686561584%) with a sentiment Neutral(0.9958131909370422% =>Community Relations)
# A spokesperson said: “We  belongs to Social(0.5086603760719299%) with a sentiment Neutral(0.9999922513961792% =>Corporate Governance)
# Our discussions are ongoi belongs to Governance(0.504309892654419%) with a sentiment Neutral(0.999940037727356% =>Corporate Governance)
# The prospect of Brexit ha belongs to Social(0.8629936575889587%) with a sentiment Negative(0.9998908042907715% =>Community Relations)
# This is because pension f belongs to None(0.9652600884437561%) with a sentiment Neutral(0.9998433589935303% =>Community Relations)
# If Green and the regulato belongs to Social(0.5569034218788147%) with a sentiment Neutral(0.9974797368049622% =>Climate Change)
# Sir Philip Green’s knight belongs to Social(0.9834902286529541%) with a sentiment Neutral(0.9999667406082153% =>Human Capital)
# Green was knighted in 200 belongs to Social(0.9822194576263428%) with a sentiment Neutral(0.999961256980896% =>Community Relations)
# However, the MPs found “l belongs to Social(0.9699676632881165%) with a sentiment Neutral(0.9657248854637146% =>Corporate Governance)
# Field also added: “What k belongs to Social(0.983359694480896%) with a sentiment Neutral(0.9999716281890869% =>Human Capital)
# Ultimately, it is the hon belongs to Governance(0.3595879077911377%) with a sentiment Neutral(0.9999929666519165% =>Corporate Governance)
# The committee will then m belongs to Governance(0.5928741097450256%) with a sentiment Neutral(0.9999980926513672% =>Corporate Governance)
# The future of Green’s kni belongs to Social(0.9524980187416077%) with a sentiment Neutral(0.9980454444885254% =>Community Relations)
# As Field has put it, the  belongs to Social(0.8856252431869507%) with a sentiment Neutral(0.9993084669113159% =>Community Relations)
# Disqualification of direc belongs to Governance(0.8983285427093506%) with a sentiment Neutral(0.7457889318466187% =>Corporate Governance)
# Chappell is accused of ha belongs to Social(0.9868708848953247%) with a sentiment Negative(0.9457611441612244% =>Human Capital)
# The other directors of hi belongs to Social(0.8943597674369812%) with a sentiment Neutral(0.9800047278404236% =>Corporate Governance)
# The corporate governance  belongs to Governance(0.6574613451957703%) with a sentiment Neutral(0.9999815225601196% =>Corporate Governance)
# This provides the grounds belongs to None(0.6966605186462402%) with a sentiment Neutral(0.8140078186988831% =>Corporate Governance)
# A spokesman for the Insol belongs to Governance(0.8574573397636414%) with a sentiment Neutral(0.8256514668464661% =>Corporate Governance)
# Directors in Green’s reta belongs to Governance(0.5890007019042969%) with a sentiment Negative(0.6184359192848206% =>Corporate Governance)
# The MPs were particularly belongs to Social(0.6540088653564453%) with a sentiment Negative(0.8697184920310974% =>Corporate Governance)
# The performance of Grabin belongs to Governance(0.8901839852333069%) with a sentiment Neutral(0.9999717473983765% =>Corporate Governance)
# The future of BHS
# No buye belongs to Social(0.9246718287467957%) with a sentiment Neutral(0.9998619556427002% =>Community Relations)
# The administrators plan t belongs to Social(0.8969708681106567%) with a sentiment Neutral(0.9999366998672485% =>Corporate Governance)
# BHS still has debts of mo belongs to Social(0.9514170289039612%) with a sentiment Neutral(0.6912592649459839% =>Community Relations)
# The taxpayer also faces a belongs to Social(0.4281288683414459%) with a sentiment Neutral(0.9894036054611206% =>Business Ethics & Values)
# Overhaul of business regu belongs to Social(0.8615972399711609%) with a sentiment Neutral(0.9699140191078186% =>Business Ethics & Values)
# This is an ambitious targ belongs to Social(0.5293933153152466%) with a sentiment Neutral(0.9976511597633362% =>Corporate Governance)
# The IoD, a lobby group fo belongs to Social(0.9890853762626648%) with a sentiment Neutral(0.9929733276367188% =>Business Ethics & Values)
# It wants the government t belongs to Social(0.6661775708198547%) with a sentiment Neutral(0.999993085861206% =>Business Ethics & Values)
# MPs on the business, inno belongs to Social(0.9081230759620667%) with a sentiment Neutral(0.9999791383743286% =>Corporate Governance)
# Britain’s pension system  belongs to Social(0.8139914870262146%) with a sentiment Neutral(0.9999918937683105% =>Community Relations)
# The BHS scandal has highl belongs to None(0.920100748538971%) with a sentiment Negative(0.999994158744812% =>Non-ESG)
# Given that UK companies h belongs to Social(0.9283727407455444%) with a sentiment Neutral(0.9245164394378662% =>Community Relations)
# Graham Vidler, director o belongs to Social(0.7741669416427612%) with a sentiment Neutral(0.9588430523872375% =>Business Ethics & Values)
# However, the different pa belongs to None(0.9309863448143005%) with a sentiment Neutral(0.5818964838981628% =>Business Ethics & Values)
# Green, for example, belie belongs to Governance(0.6697045564651489%) with a sentiment Negative(0.9200589656829834% =>Business Ethics & Values)
# … we have a small favour  belongs to Social(0.9139536023139954%) with a sentiment Neutral(0.9987610578536987% =>Business Ethics & Values)
# Millions are turning to t belongs to Social(0.9856540560722351%) with a sentiment Neutral(0.918123185634613% =>Community Relations)
# We believe everyone deser belongs to Social(0.9685161709785461%) with a sentiment Neutral(0.9675382375717163% =>Business Ethics & Values)
# That’s why we made a diff belongs to Social(0.944110631942749%) with a sentiment Neutral(0.9999629259109497% =>Corporate Governance)
# This means more people ca belongs to Social(0.9827892184257507%) with a sentiment Positive(0.9999990463256836% =>Human Capital)
# In these perilous times,  belongs to Social(0.9859711527824402%) with a sentiment Neutral(0.9999626874923706% =>Community Relations)
# We have no shareholders o belongs to Social(0.630013108253479%) with a sentiment Neutral(0.9998953342437744% =>Business Ethics & Values)
# When it’s never been more belongs to Social(0.9622717499732971%) with a sentiment Positive(0.6617771983146667% =>Business Ethics & Values)

# %%
df_csv = pd.DataFrame(dataset_lst)

# %%
df_csv
# Out:
#                                              sentence    topic_label  \
# 0   Fallout from the scandal could lead to a lost ...     Governance
# 1   The damning parliamentary report into the demi...         Social
# 2   The BHS scandal has been described by MPs as t...  Environmental
# 3   Dominic Chappell, the businessman who bought B...         Social
# 4   The fallout from the scandal could lead to a k...     Governance
# 5   Around 11,000 jobs are at risk after BHS colla...         Social
# 6   Green controlled BHS for 15 years until March ...         Social
# 7   Green and other shareholders extracted £586m i...     Governance
# 8   Pensions\nBHS has been left with a pension def...           None
# 9   Green told MPs that problems facing the pensio...         Social
# 10  He added: “We will sort it, we will find a sol...         Social
# 11  “His family took out of BHS and Arcadia a fort...         Social
# 12  The Pensions Regulator, which could force Gree...           None
# 13  A spokesperson said: “We met with Sir Philip a...         Social
# 14  Our discussions are ongoing and we will not be...     Governance
# 15  The prospect of Brexit has led to yields on go...         Social
# 16  This is because pension funds hold gilts in th...           None
# 17  If Green and the regulator cannot agree a deal...         Social
# 18  Sir Philip Green’s knighthood\nThe report by t...         Social
# 19  Green was knighted in 2006 by Tony Blair’s gov...         Social
# 20  However, the MPs found “little to support the ...         Social
# 21  Field also added: “What kind of man is it who ...         Social
# 22  Ultimately, it is the honours forfeiture commi...     Governance
# 23  The committee will then make a recommendation ...     Governance
# 24  The future of Green’s knighthood is now likely...         Social
# 25  As Field has put it, the billionaire needs to ...         Social
# 26  Disqualification of directors\nThe collapse of...     Governance
# 27  Chappell is accused of having his “hands in th...         Social
# 28  The other directors of his consortium, Retail ...         Social
# 29  The corporate governance of Retail Acquisition...     Governance
# 30  This provides the grounds for the Insolvency S...           None
# 31  A spokesman for the Insolvency Service confirm...     Governance
# 32  Directors in Green’s retail empire could also ...     Governance
# 33  The MPs were particularly critical of Lord Gra...         Social
# 34  The performance of Grabiner, who earned £125,0...     Governance
# 35  The future of BHS\nNo buyer has been found for...         Social
# 36  The administrators plan to close all the compa...         Social
# 37  BHS still has debts of more than £1.1bn, inclu...         Social
# 38  The taxpayer also faces a bill of up to £36m f...         Social
# 39  Overhaul of business regulation\nTheresa May w...         Social
# 40  This is an ambitious target, but company bosse...         Social
# 41  The IoD, a lobby group for business leaders, s...         Social
# 42  It wants the government to look into how large...         Social
# 43  MPs on the business, innovation and skills com...         Social
# 44  Britain’s pension system also needs to be revi...         Social
# 45  The BHS scandal has highlighted problems with ...           None
# 46  Given that UK companies have a combined pensio...         Social
# 47  Graham Vidler, director of external affairs at...         Social
# 48  However, the different parties involved in the...           None
# 49  Green, for example, believes he has grounds to...     Governance
# 50                   … we have a small favour to ask.         Social
# 51  Millions are turning to the Guardian for open,...         Social
# 52  We believe everyone deserves access to informa...         Social
# 53  That’s why we made a different choice: to keep...         Social
# 54  This means more people can be better informed,...         Social
# 55  In these perilous times, a truth-seeking globa...         Social
# 56  We have no shareholders or billionaire owner, ...         Social
# 57  When it’s never been more important, our indep...         Social
#
#     topic_score sentiment_label  sentiment_score         fls_label  fls_score  \
# 0      0.453123        Negative         0.999860  Non-specific FLS   0.937266
# 1      0.978643        Negative         0.999710  Non-specific FLS   0.708357
# 2      0.931507        Negative         0.959220           Not FLS   0.990499
# 3      0.957609         Neutral         0.999972           Not FLS   0.993661
# 4      0.408408        Negative         0.998442  Non-specific FLS   0.935790
# 5      0.982828        Negative         0.727773           Not FLS   0.644578
# 6      0.970641         Neutral         0.999325           Not FLS   0.986811
# 7      0.641291         Neutral         0.999768           Not FLS   0.989532
# 8      0.912101        Negative         0.881347           Not FLS   0.991116
# 9      0.968416        Negative         0.977430           Not FLS   0.988535
# 10     0.966605        Negative         0.999928           Not FLS   0.899197
# 11     0.970421         Neutral         0.993508           Not FLS   0.980762
# 12     0.773174         Neutral         0.995813           Not FLS   0.973992
# 13     0.508660         Neutral         0.999992           Not FLS   0.987530
# 14     0.504310         Neutral         0.999940  Non-specific FLS   0.674740
# 15     0.862994        Negative         0.999891           Not FLS   0.974512
# 16     0.965260         Neutral         0.999843           Not FLS   0.986217
# 17     0.556903         Neutral         0.997480  Non-specific FLS   0.614329
# 18     0.983490         Neutral         0.999967           Not FLS   0.972337
# 19     0.982219         Neutral         0.999961           Not FLS   0.991741
# 20     0.969968         Neutral         0.965725           Not FLS   0.991863
# 21     0.983360         Neutral         0.999972           Not FLS   0.973491
# 22     0.359588         Neutral         0.999993  Non-specific FLS   0.659751
# 23     0.592874         Neutral         0.999998  Non-specific FLS   0.573634
# 24     0.952498         Neutral         0.998045  Non-specific FLS   0.622813
# 25     0.885625         Neutral         0.999308           Not FLS   0.777880
# 26     0.898329         Neutral         0.745789           Not FLS   0.932712
# 27     0.986871        Negative         0.945761           Not FLS   0.987494
# 28     0.894360         Neutral         0.980005           Not FLS   0.990757
# 29     0.657461         Neutral         0.999982           Not FLS   0.992372
# 30     0.696661         Neutral         0.814008           Not FLS   0.987760
# 31     0.857457         Neutral         0.825651           Not FLS   0.988018
# 32     0.589001        Negative         0.618436  Non-specific FLS   0.890371
# 33     0.654009        Negative         0.869718           Not FLS   0.989915
# 34     0.890184         Neutral         0.999972           Not FLS   0.992430
# 35     0.924672         Neutral         0.999862           Not FLS   0.981290
# 36     0.896971         Neutral         0.999937      Specific FLS   0.939617
# 37     0.951417         Neutral         0.691259      Specific FLS   0.531967
# 38     0.428129         Neutral         0.989404           Not FLS   0.986426
# 39     0.861597         Neutral         0.969914  Non-specific FLS   0.691792
# 40     0.529393         Neutral         0.997651           Not FLS   0.945916
# 41     0.989085         Neutral         0.992973           Not FLS   0.989583
# 42     0.666178         Neutral         0.999993           Not FLS   0.956127
# 43     0.908123         Neutral         0.999979      Specific FLS   0.562518
# 44     0.813991         Neutral         0.999992           Not FLS   0.700235
# 45     0.920101        Negative         0.999994           Not FLS   0.987249
# 46     0.928373         Neutral         0.924516  Non-specific FLS   0.589241
# 47     0.774167         Neutral         0.958843           Not FLS   0.538619
# 48     0.930986         Neutral         0.581896           Not FLS   0.676792
# 49     0.669705        Negative         0.920059           Not FLS   0.987530
# 50     0.913954         Neutral         0.998761           Not FLS   0.932676
# 51     0.985654         Neutral         0.918123           Not FLS   0.937516
# 52     0.968516         Neutral         0.967538           Not FLS   0.989762
# 53     0.944111         Neutral         0.999963           Not FLS   0.987964
# 54     0.982789        Positive         0.999999           Not FLS   0.870280
# 55     0.985971         Neutral         0.999963           Not FLS   0.979315
# 56     0.630013         Neutral         0.999895           Not FLS   0.984317
# 57     0.962272        Positive         0.661777           Not FLS   0.966465
#
#                sub_cat_label  sub_cat_score
# 0   Business Ethics & Values       0.983647
# 1        Community Relations       0.773190
# 2          Pollution & Waste       0.551511
# 3          Product Liability       0.327208
# 4   Business Ethics & Values       0.983201
# 5              Human Capital       0.948250
# 6        Community Relations       0.530825
# 7       Corporate Governance       0.984617
# 8        Community Relations       0.335942
# 9        Community Relations       0.538749
# 10      Corporate Governance       0.873386
# 11      Corporate Governance       0.506842
# 12       Community Relations       0.435189
# 13      Corporate Governance       0.977946
# 14      Corporate Governance       0.435861
# 15       Community Relations       0.728123
# 16       Community Relations       0.663802
# 17            Climate Change       0.447276
# 18             Human Capital       0.902188
# 19       Community Relations       0.817322
# 20      Corporate Governance       0.506047
# 21             Human Capital       0.958489
# 22      Corporate Governance       0.980109
# 23      Corporate Governance       0.931020
# 24       Community Relations       0.937683
# 25       Community Relations       0.478630
# 26      Corporate Governance       0.989799
# 27             Human Capital       0.439784
# 28      Corporate Governance       0.988698
# 29      Corporate Governance       0.902939
# 30      Corporate Governance       0.986591
# 31      Corporate Governance       0.951162
# 32      Corporate Governance       0.988332
# 33      Corporate Governance       0.991131
# 34      Corporate Governance       0.986014
# 35       Community Relations       0.744183
# 36      Corporate Governance       0.618253
# 37       Community Relations       0.824308
# 38  Business Ethics & Values       0.288109
# 39  Business Ethics & Values       0.936832
# 40      Corporate Governance       0.980766
# 41  Business Ethics & Values       0.904159
# 42  Business Ethics & Values       0.804943
# 43      Corporate Governance       0.598579
# 44       Community Relations       0.856560
# 45                   Non-ESG       0.465722
# 46       Community Relations       0.779904
# 47  Business Ethics & Values       0.960764
# 48  Business Ethics & Values       0.447106
# 49  Business Ethics & Values       0.968400
# 50  Business Ethics & Values       0.425599
# 51       Community Relations       0.959957
# 52  Business Ethics & Values       0.915756
# 53      Corporate Governance       0.721066
# 54             Human Capital       0.968285
# 55       Community Relations       0.875926
# 56  Business Ethics & Values       0.740604
# 57  Business Ethics & Values       0.722080

# %%
df_csv.to_csv('Data/labeled_sentences_negative_G_58_extra_classes.csv')
