# %%
from nltk import tokenize
import pandas as pd
import re
import textract

# %%
data = textract.process('Data/apmm-sustainability-report-a4_2017.pdf')
data = re.split(b'\s{4,}',data)
data = [sentence.decode() for sentence in data if len(sentence)>70 and len(sentence)<500]
data = ' '.join(data)

# %%
# tested in transformers==4.18.0 
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

finbert = AutoModelForSequenceClassification.from_pretrained('Models/topic_model/',num_labels=4)
tokenizer = AutoTokenizer.from_pretrained('Models/topic_tokenizer/')
nlp = pipeline("text-classification", model=finbert, tokenizer=tokenizer)

# %%
finbert_sentiment = AutoModelForSequenceClassification.from_pretrained('Models/sentiment_model/',num_labels=3)
tokenizer_sentiment = AutoTokenizer.from_pretrained('Models/sentiment_tokenizer/')
nlp_sentiment = pipeline("text-classification", model=finbert_sentiment, tokenizer=tokenizer_sentiment)

# %%
finbert_fls = AutoModelForSequenceClassification.from_pretrained('Models/fls_model/',num_labels=3)
tokenizer_fls = AutoTokenizer.from_pretrained('Models/fls_tokenizer/')
nlp_fls = pipeline("text-classification", model=finbert_fls, tokenizer=tokenizer_fls)

# %%
finbert_sub_cat = AutoModelForSequenceClassification.from_pretrained('Models/subESG_model/',num_labels=9)
tokenizer_sub_cat = AutoTokenizer.from_pretrained('Models/subESG_tokenizer/')
nlp_sub_cat = pipeline("text-classification", model=finbert_sub_cat, tokenizer=tokenizer_sub_cat)

# %%
list_all_sentences = tokenize.sent_tokenize(data)
len(list_all_sentences)
# Out:
# 376

# %%
list_all_sentences_short = [sentence for sentence in list_all_sentences if len(sentence)<500]
len(list_all_sentences_short)
# Out:
# 365

# %%
def build_dataset(lst):
    try:
        dataset_lst = []
        for sentence in lst :
            topic_label= nlp(sentence)[0]['label']
            topic_score = nlp(sentence)[0]['score']
            
            sentiment_label = nlp_sentiment(sentence)[0]['label']
            sentiment_score = nlp_sentiment(sentence)[0]['score']
            
            fls_label = nlp_fls(sentence)[0]['label']
            fls_score = nlp_fls(sentence)[0]['score']
            
            sub_cat_label = nlp_sub_cat(sentence)[0]['label']
            sub_cat_score = nlp_sub_cat(sentence)[0]['score']
            
            print(f'{sentence[0:25]} belongs to {topic_label}({topic_score}%) with a sentiment {sentiment_label}({sentiment_score}% =>{sub_cat_label})')
            dataset_lst.append({'sentence':sentence,
                                'topic_label': topic_label,
                                'topic_score': topic_score,
                                'sentiment_label': sentiment_label,
                                'sentiment_score': sentiment_score,
                                'fls_label': fls_label,
                                'fls_score': fls_score,
                                'sub_cat_label': sub_cat_label,
                                'sub_cat_score': sub_cat_score                                
                                })
    except:
        dataset_lst.append({'sentence':sentence,
                                'topic_label': 'error',
                                'topic_score': 0,
                                'sentiment_label': 'error',
                                'sentiment_score': 0,
                                'fls_label': 'error',
                                'fls_score': 0,
                                'sub_cat_label': 'error',
                                'sub_cat_score': 0})
    return dataset_lst

# %%
dataset_lst = build_dataset(list_all_sentences_short)
# Out:
# Companies can no longer s belongs to Social(0.9573908448219299%) with a sentiment Neutral(0.99234938621521% =>Non-ESG)
# Our business
# A.P. belongs to None(0.9767014980316162%) with a sentiment Neutral(0.9984109401702881% =>Non-ESG)
# Moller - Maersk employs o belongs to Social(0.9824466705322266%) with a sentiment Neutral(0.999998927116394% =>Human Capital)
# Our vision is to be the g belongs to Social(0.9548644423484802%) with a sentiment Positive(0.9310210943222046% =>Product Liability)
# Examples of where some of belongs to Environmental(0.7603691816329956%) with a sentiment Neutral(0.9751501083374023% =>Pollution & Waste)
# A world-leading provider  belongs to Social(0.843917965888977%) with a sentiment Neutral(0.5442354679107666% =>Community Relations)
# Moller - Maersk has been  belongs to Social(0.9871279001235962%) with a sentiment Positive(0.9999998807907104% =>Community Relations)
# We plan to still be doing belongs to Social(0.7782077789306641%) with a sentiment Neutral(0.9991421699523926% =>Non-ESG)
# However, the way we fill  belongs to Social(0.9370781183242798%) with a sentiment Neutral(0.9999746084213257% =>Human Capital)
# Transforming our business belongs to Social(0.9551233053207397%) with a sentiment Positive(0.9998644590377808% =>Community Relations)
# Moller - Maersk is prepar belongs to Environmental(0.9017252326011658%) with a sentiment Positive(0.9840077757835388% =>Pollution & Waste)
# Our business touches,
# di belongs to Social(0.9114271998405457%) with a sentiment Neutral(0.9999985694885254% =>Product Liability)
# Effects of reducing barri belongs to Social(0.9171051979064941%) with a sentiment Neutral(0.8290858864784241% =>Business Ethics & Values)
# Moller - Maersk has pilot belongs to Social(0.9906266927719116%) with a sentiment Neutral(0.9996933937072754% =>Community Relations)
# jobs can potentially
# be  belongs to Social(0.9867620468139648%) with a sentiment Positive(0.9993755221366882% =>Community Relations)
#  belongs to Social(0.9005071520805359%) with a sentiment Positive(0.9808170795440674% =>Climate Change)
# increase in real income f belongs to None(0.9836916923522949%) with a sentiment Positive(0.9998786449432373% =>Community Relations)
# CONNECTAMERICAS
# An onlin belongs to Social(0.6573664546012878%) with a sentiment Neutral(0.7265589833259583% =>Non-ESG)
# This potentially
# distrib belongs to Social(0.9665573239326477%) with a sentiment Positive(0.9995933175086975% =>Community Relations)
# The project is fully
# ope belongs to None(0.9864572882652283%) with a sentiment Neutral(0.9999918937683105% =>Non-ESG)
# increase in real income
#  belongs to None(0.9769600629806519%) with a sentiment Positive(0.9999444484710693% =>Community Relations)
# Global income distributio belongs to None(0.6594452857971191%) with a sentiment Negative(0.9986647367477417% =>Community Relations)
# Revista de Economía Insti belongs to Social(0.9434184432029724%) with a sentiment Neutral(0.9955825209617615% =>Community Relations)
# It will decrease
# time to belongs to Social(0.5829073190689087%) with a sentiment Positive(0.9880788922309875% =>Non-ESG)
# To me, the fact that what belongs to Social(0.6246057748794556%) with a sentiment Positive(0.999998927116394% =>Business Ethics & Values)
# Our vision of simplifying belongs to Social(0.9717760682106018%) with a sentiment Positive(0.9503486752510071% =>Human Capital)
# The work we do connecting belongs to Social(0.9847254157066345%) with a sentiment Positive(1.0% =>Business Ethics & Values)
# Inspired by the ConnectAm belongs to Social(0.8737416863441467%) with a sentiment Positive(0.9997259974479675% =>Product Liability)
# Investments in Bitung por belongs to Social(0.8595845103263855%) with a sentiment Positive(0.9996121525764465% =>Natural Capital)
# While creating benefits s belongs to Social(0.828151285648346%) with a sentiment Neutral(0.6076937317848206% =>Non-ESG)
#  belongs to Environmental(0.980038583278656%) with a sentiment Neutral(0.9176898002624512% =>Climate Change)
# Third IMO Greenhouse Gas  belongs to Environmental(0.9865871071815491%) with a sentiment Neutral(0.997455894947052% =>Climate Change)
# Improvements in the pipel belongs to None(0.9194567799568176%) with a sentiment Positive(1.0% =>Non-ESG)
# First of all, we will rec belongs to Environmental(0.9892445802688599%) with a sentiment Neutral(0.9997738003730774% =>Climate Change)
# SUPPORTING
# DISCLOSURE
# A belongs to None(0.9337798953056335%) with a sentiment Neutral(0.9984305500984192% =>Non-ESG)
# Moller - Maersk
# is a sig belongs to Environmental(0.9885713458061218%) with a sentiment Neutral(0.9999961853027344% =>Climate Change)
# cargo as well as guarante belongs to None(0.7728695869445801%) with a sentiment Neutral(0.9994556307792664% =>Non-ESG)
# The centre has been in op belongs to Environmental(0.975948691368103%) with a sentiment Positive(0.8273273706436157% =>Climate Change)
# With the roll-out of
# the belongs to Environmental(0.926050066947937%) with a sentiment Positive(0.9999982118606567% =>Climate Change)
# of the global market
# for belongs to Social(0.58625727891922%) with a sentiment Neutral(0.9999988079071045% =>Pollution & Waste)
# Moller - Maersk. belongs to None(0.9263724088668823%) with a sentiment Neutral(0.9961748123168945% =>Non-ESG)
# Taking on the food
# loss  belongs to Social(0.7427257299423218%) with a sentiment Neutral(0.9312145709991455% =>Product Liability)
# By 2050, food demand is
#  belongs to Social(0.9239148497581482%) with a sentiment Positive(0.9887005686759949% =>Community Relations)
# Already, some 800 million belongs to Environmental(0.8122958540916443%) with a sentiment Neutral(0.780210554599762% =>Pollution & Waste)
# Of all food loss, one-thi belongs to Environmental(0.8623306155204773%) with a sentiment Neutral(0.9998550415039062% =>Pollution & Waste)
# Key factors causing
# this belongs to Social(0.536087691783905%) with a sentiment Negative(0.9999909400939941% =>Pollution & Waste)
# Combining opportunity
# an belongs to Social(0.9038881659507751%) with a sentiment Positive(0.9991300702095032% =>Human Capital)
# Moller - Maersk holds abo belongs to Environmental(0.695094108581543%) with a sentiment Neutral(0.9999996423721313% =>Pollution & Waste)
# Our ambition is to
# use o belongs to Social(0.9661573171615601%) with a sentiment Positive(0.9999805688858032% =>Product Liability)
# Governance and materialit belongs to Governance(0.9198188185691833%) with a sentiment Neutral(0.9962211847305298% =>Corporate Governance)
# ince September 2016, A.P. belongs to None(0.7406641840934753%) with a sentiment Neutral(0.996350884437561% =>Non-ESG)
# Moller Maersk has been tr belongs to None(0.4688665568828583%) with a sentiment Neutral(0.974959135055542% =>Non-ESG)
# This change offers a new  belongs to Social(0.8128763437271118%) with a sentiment Neutral(0.9995647072792053% =>Corporate Governance)
# Solidifying materiality
#  belongs to Social(0.8864898681640625%) with a sentiment Neutral(0.9629762172698975% =>Product Liability)
# OUR COMMITMENT TO SUSTAIN belongs to Social(0.9188058972358704%) with a sentiment Positive(0.8680679798126221% =>Natural Capital)
# Moller - Maersk
# business belongs to None(0.9833647608757019%) with a sentiment Neutral(0.9999760389328003% =>Non-ESG)
# In everything we do withi belongs to Social(0.9318987727165222%) with a sentiment Neutral(0.9995278120040894% =>Natural Capital)
# Moller - Maersk is commit belongs to Social(0.8732986450195312%) with a sentiment Positive(0.9970593452453613% =>Human Capital)
# • We define corporate sus belongs to Social(0.7453653216362%) with a sentiment Positive(0.9999502897262573% =>Human Capital)
# • We further aim to unloc belongs to Social(0.966324508190155%) with a sentiment Positive(0.9999252557754517% =>Community Relations)
# Moller - Maersk
# by lever belongs to Social(0.9833623766899109%) with a sentiment Positive(0.999996542930603% =>Product Liability)
# The companies in the Ener belongs to Social(0.6415985226631165%) with a sentiment Neutral(0.9993452429771423% =>Climate Change)
# assesses and groups issue belongs to Social(0.4851033091545105%) with a sentiment Neutral(0.9999746084213257% =>Human Capital)
# This
# takes us beyond the belongs to None(0.4188409745693207%) with a sentiment Neutral(0.8301775455474854% =>Corporate Governance)
# With our new approach, we belongs to Governance(0.39974892139434814%) with a sentiment Positive(0.7396892309188843% =>Corporate Governance)
# Changes made in 2017
# In  belongs to Governance(0.6293769478797913%) with a sentiment Neutral(0.9991538524627686% =>Corporate Governance)
# Sustainability risks that belongs to Governance(0.810215950012207%) with a sentiment Neutral(0.9994655251502991% =>Corporate Governance)
# As part of this
# process, belongs to Social(0.7823460102081299%) with a sentiment Neutral(0.9130478501319885% =>Non-ESG)
# We found
# neither of thes belongs to Environmental(0.47850996255874634%) with a sentiment Neutral(0.9999963045120239% =>Product Liability)
# THE 2017 A.P. belongs to None(0.9758801460266113%) with a sentiment Neutral(0.9999536275863647% =>Non-ESG)
# MOLLER - MAERSK SUSTAINAB belongs to Social(0.9496463537216187%) with a sentiment Positive(1.0% =>Climate Change)
# The involvement
# of the e belongs to Social(0.9758106470108032%) with a sentiment Positive(0.7772513628005981% =>Community Relations)
# Moller - Maersk
# Drive pr belongs to Social(0.7479830980300903%) with a sentiment Neutral(0.8943219184875488% =>Corporate Governance)
# Moller - Maersk strengthe belongs to Governance(0.8409289121627808%) with a sentiment Positive(0.9829628467559814% =>Corporate Governance)
# 1 The A.P. belongs to None(0.9589126110076904%) with a sentiment Neutral(0.9998224377632141% =>Non-ESG)
# Moller - Maersk governanc belongs to Social(0.9533277153968811%) with a sentiment Positive(0.9999963045120239% =>Business Ethics & Values)
# A.P. belongs to None(0.9518617391586304%) with a sentiment Neutral(0.9990792274475098% =>Non-ESG)
# Moller - Maersk
# Core Val belongs to Social(0.9710756540298462%) with a sentiment Neutral(0.9998859167098999% =>Human Capital)
# risk, responsibility
# and belongs to Social(0.8072502613067627%) with a sentiment Neutral(0.9994262456893921% =>Corporate Governance)
# Do our values and commitm belongs to None(0.48965129256248474%) with a sentiment Neutral(0.9719040393829346% =>Business Ethics & Values)
# Does A.P. belongs to None(0.956861674785614%) with a sentiment Neutral(0.9997630715370178% =>Non-ESG)
# Moller - Maersk have sign belongs to None(0.9400690197944641%) with a sentiment Neutral(0.9848137497901917% =>Non-ESG)
# Is A.P. belongs to None(0.9529566764831543%) with a sentiment Neutral(0.9999363422393799% =>Non-ESG)
# Moller - Maersk able to d belongs to Social(0.6812663078308105%) with a sentiment Positive(0.9743099808692932% =>Product Liability)
# Can we drive collective a belongs to Social(0.9777476191520691%) with a sentiment Neutral(0.9982099533081055% =>Human Capital)
# Does the issue present a  belongs to None(0.827347457408905%) with a sentiment Negative(0.9929521679878235% =>Business Ethics & Values)
# Moller - Maersk’s ability belongs to None(0.7537739872932434%) with a sentiment Positive(0.8542879819869995% =>Non-ESG)
# Prioritise material issue belongs to Environmental(0.9573655128479004%) with a sentiment Neutral(0.9835036993026733% =>Human Capital)
# RISK
# Where do sustainabi belongs to Governance(0.737909197807312%) with a sentiment Negative(0.9997666478157043% =>Business Ethics & Values)
# Issues: Injuries and fata belongs to Social(0.9860100746154785%) with a sentiment Negative(0.9999260902404785% =>Human Capital)
# Moller - Maersk Third-Par belongs to Social(0.8900895714759827%) with a sentiment Positive(0.9998571872711182% =>Business Ethics & Values)
# Responsible
# business pra belongs to Governance(0.8092142939567566%) with a sentiment Neutral(0.998753547668457% =>Business Ethics & Values)
# Moller - Maersk has set i belongs to Social(0.8747831583023071%) with a sentiment Positive(0.999921441078186% =>Non-ESG)
# We will be
# offering solu belongs to None(0.6575443148612976%) with a sentiment Neutral(0.9999516010284424% =>Product Liability)
# Working in accordance wit belongs to Social(0.9458813071250916%) with a sentiment Neutral(0.985094428062439% =>Business Ethics & Values)
# This means we will assess belongs to Social(0.9042581915855408%) with a sentiment Neutral(0.9963250756263733% =>Product Liability)
# It will start with our su belongs to Environmental(0.9554982781410217%) with a sentiment Neutral(0.9999984502792358% =>Pollution & Waste)
# We are guided by the comm belongs to Social(0.7449523210525513%) with a sentiment Neutral(0.9998449087142944% =>Business Ethics & Values)
# We are also committed
# to belongs to Social(0.9792630076408386%) with a sentiment Neutral(0.8390214443206787% =>Human Capital)
# Safety at work is a basic belongs to Social(0.9853780269622803%) with a sentiment Neutral(0.9998302459716797% =>Human Capital)
# Furthermore, workplace co belongs to Social(0.9885178804397583%) with a sentiment Neutral(0.999718964099884% =>Human Capital)
# Respect for human rights  belongs to Social(0.8582672476768494%) with a sentiment Neutral(0.9999853372573853% =>Human Capital)
#  belongs to Social(0.9710822105407715%) with a sentiment Positive(0.9999997615814209% =>Community Relations)
# Discrimination bars peopl belongs to Social(0.9875653386116028%) with a sentiment Neutral(0.515495777130127% =>Community Relations)
# In line with our values a belongs to Social(0.9872862696647644%) with a sentiment Neutral(0.9992019534111023% =>Human Capital)
# Keeping our people safe i belongs to Social(0.9610412120819092%) with a sentiment Neutral(0.8013395071029663% =>Human Capital)
# It is
# a core value for u belongs to Social(0.9627199172973633%) with a sentiment Positive(0.999657392501831% =>Human Capital)
# It is a basic obligation  belongs to Social(0.9503817558288574%) with a sentiment Neutral(0.9638398885726929% =>Human Capital)
# The ultimate risk related belongs to Social(0.9806911945343018%) with a sentiment Negative(0.9927958846092224% =>Human Capital)
# Such events may carry bus belongs to None(0.910798966884613%) with a sentiment Negative(0.999870777130127% =>Non-ESG)
# Reputational damage may o belongs to Social(0.9852956533432007%) with a sentiment Negative(0.9997630715370178% =>Human Capital)
# Financial damages may
# oc belongs to None(0.9839211702346802%) with a sentiment Neutral(0.5952466726303101% =>Business Ethics & Values)
# Talent is diverse by natu belongs to Social(0.9451104998588562%) with a sentiment Neutral(0.9999926090240479% =>Human Capital)
# It is about being able
# t belongs to Social(0.988900899887085%) with a sentiment Positive(1.0% =>Human Capital)
# The CEOs of each business belongs to Social(0.9715167284011841%) with a sentiment Neutral(0.9999710321426392% =>Human Capital)
# Work is coordinated acros belongs to Social(0.9570791125297546%) with a sentiment Neutral(0.9999874830245972% =>Human Capital)
# Gap assessment and action belongs to Social(0.9785237312316895%) with a sentiment Neutral(0.9999635219573975% =>Human Capital)
# Labour relations Commit r belongs to Social(0.8662394881248474%) with a sentiment Neutral(0.9999545812606812% =>Human Capital)
# Our overriding ambition i belongs to Social(0.9902410507202148%) with a sentiment Neutral(0.7737244367599487% =>Community Relations)
# We strive to ensure that  belongs to Social(0.9887651205062866%) with a sentiment Neutral(0.7757724523544312% =>Human Capital)
# We aspire to build a cult belongs to Social(0.9866607189178467%) with a sentiment Positive(0.9999164342880249% =>Human Capital)
# Zero fatalities. belongs to Social(0.9279599785804749%) with a sentiment Neutral(0.687508761882782% =>Human Capital)
# Continuous improvement in belongs to Social(0.9688905477523804%) with a sentiment Positive(0.9999991655349731% =>Human Capital)
# Targets for representatio belongs to Social(0.9696816205978394%) with a sentiment Neutral(0.9999997615814209% =>Corporate Governance)
# The number of fatalities  belongs to Social(0.9731340408325195%) with a sentiment Neutral(0.7476868033409119% =>Human Capital)
# Lost time injury frequenc belongs to Social(0.8958932757377625%) with a sentiment Neutral(0.9801602959632874% =>Human Capital)
# See p. 29 for
# individual belongs to None(0.9932331442832947%) with a sentiment Neutral(0.9998798370361328% =>Non-ESG)
# Rolled out a new human ri belongs to Social(0.9872778654098511%) with a sentiment Neutral(0.9629486799240112% =>Human Capital)
# Progress has been made on belongs to Social(0.6620733737945557%) with a sentiment Neutral(0.9916343688964844% =>Human Capital)
# New
# strategy for diversi belongs to Social(0.9410277009010315%) with a sentiment Positive(0.7406073808670044% =>Human Capital)
# Training of staff on labo belongs to Social(0.9873807430267334%) with a sentiment Neutral(0.9998181462287903% =>Human Capital)
# Large-scale oil spills ma belongs to Environmental(0.8444501161575317%) with a sentiment Negative(0.8206595778465271% =>Pollution & Waste)
# The air emissions from oc belongs to Environmental(0.980428159236908%) with a sentiment Negative(0.9999929666519165% =>Climate Change)
# Ocean health is pivotal t belongs to Social(0.9893686175346375%) with a sentiment Neutral(0.6736694574356079% =>Natural Capital)
# The prevalence
# of, for e belongs to Environmental(0.5222721695899963%) with a sentiment Negative(0.9975220561027527% =>Pollution & Waste)
# The trust in our brand wi belongs to Social(0.9806109666824341%) with a sentiment Negative(0.9998705387115479% =>Product Liability)
# Major spills and accident belongs to Social(0.46293166279792786%) with a sentiment Negative(0.8237109184265137% =>Pollution & Waste)
# Our business may
# suffer  belongs to None(0.9140322804450989%) with a sentiment Negative(0.9998693466186523% =>Business Ethics & Values)
# Emissions from our activi belongs to Environmental(0.989586591720581%) with a sentiment Neutral(0.9958775043487549% =>Climate Change)
# As a citizen of
# the ocea belongs to Social(0.9740878939628601%) with a sentiment Neutral(0.8128968477249146% =>Natural Capital)
# We operate in a highly co belongs to Environmental(0.9385703802108765%) with a sentiment Negative(0.9900391697883606% =>Non-ESG)
# Our commitments and value belongs to Environmental(0.9208276271820068%) with a sentiment Neutral(0.9984022974967957% =>Business Ethics & Values)
# We control the risk of sp belongs to Environmental(0.9209026098251343%) with a sentiment Neutral(0.9872331619262695% =>Pollution & Waste)
# We strive to minimise our belongs to Environmental(0.9749342203140259%) with a sentiment Positive(0.5636315941810608% =>Natural Capital)
# Less predictable weather  belongs to Environmental(0.9815903306007385%) with a sentiment Negative(0.9995468258857727% =>Climate Change)
# Commit Rule on Responsibl belongs to Social(0.9428491592407227%) with a sentiment Neutral(0.9999871253967285% =>Corporate Governance)
# The CEO of each business  belongs to Governance(0.8819046020507812%) with a sentiment Neutral(0.9999972581863403% =>Corporate Governance)
# Our regulatory work is gu belongs to Social(0.9568858742713928%) with a sentiment Neutral(0.9999843835830688% =>Corporate Governance)
# Operationally, our effort belongs to Environmental(0.990676999092102%) with a sentiment Neutral(0.9969605803489685% =>Climate Change)
# Our work on healthy ocean belongs to Social(0.7968320250511169%) with a sentiment Neutral(0.9999823570251465% =>Natural Capital)
# Operationally, our effort belongs to Environmental(0.990676999092102%) with a sentiment Neutral(0.9969605803489685% =>Climate Change)
# Ensure compliance with Co belongs to Governance(0.8573814630508423%) with a sentiment Positive(0.7823336720466614% =>Business Ethics & Values)
# Determine the baseline of belongs to Social(0.8449914455413818%) with a sentiment Neutral(0.9999489784240723% =>Corporate Governance)
# Zero spills, as defined i belongs to None(0.8955044150352478%) with a sentiment Neutral(0.9998437166213989% =>Pollution & Waste)
# Moller - Maersk’s
# Sustai belongs to Governance(0.4856167137622833%) with a sentiment Neutral(0.999845027923584% =>Climate Change)
# To mitigate the risk, our belongs to Social(0.7682349681854248%) with a sentiment Positive(0.8302014470100403% =>Business Ethics & Values)
# Support the science commu belongs to Social(0.9336932301521301%) with a sentiment Positive(0.9975825548171997% =>Natural Capital)
# Ensure compliance with Co belongs to Governance(0.8573814630508423%) with a sentiment Positive(0.7823336720466614% =>Business Ethics & Values)
# Perform 70 audits, includ belongs to Social(0.9774898886680603%) with a sentiment Neutral(0.9999538660049438% =>Corporate Governance)
# Zero non-contained spills belongs to None(0.8632662892341614%) with a sentiment Neutral(0.9999257326126099% =>Pollution & Waste)
# Moller - Maersk’s Sustain belongs to Governance(0.4856167137622833%) with a sentiment Neutral(0.999845027923584% =>Climate Change)
# Maintain or implement sol belongs to Governance(0.9151502847671509%) with a sentiment Neutral(0.5074081420898438% =>Business Ethics & Values)
# Develop positions alone a belongs to None(0.7935638427734375%) with a sentiment Neutral(0.9999681711196899% =>Human Capital)
# Fully comply with regulat belongs to Governance(0.6673534512519836%) with a sentiment Positive(0.8356078863143921% =>Business Ethics & Values)
# Mature the partnership wi belongs to Social(0.9885343909263611%) with a sentiment Neutral(0.999981164932251% =>Community Relations)
# Explore partnership oppor belongs to Social(0.5150229334831238%) with a sentiment Neutral(0.5840274095535278% =>Community Relations)
# Approval of a new priorit belongs to Social(0.968207061290741%) with a sentiment Positive(0.7906640768051147% =>Human Capital)
# 68 audits performed, 569  belongs to Governance(0.8206908702850342%) with a sentiment Neutral(0.9999943971633911% =>Corporate Governance)
# 33 training workshops for belongs to Social(0.9781769514083862%) with a sentiment Neutral(0.9999798536300659% =>Human Capital)
# Simplification of respons belongs to Governance(0.6014893054962158%) with a sentiment Positive(0.9918888211250305% =>Corporate Governance)
# Zero non-contained spills belongs to None(0.8632662892341614%) with a sentiment Neutral(0.9999257326126099% =>Pollution & Waste)
# Moller - Maersk’s Sustain belongs to Governance(0.4856167137622833%) with a sentiment Neutral(0.999845027923584% =>Climate Change)
# Position established on t belongs to Environmental(0.9865755438804626%) with a sentiment Neutral(0.9992389678955078% =>Climate Change)
# Measures to comply with r belongs to Environmental(0.9899157881736755%) with a sentiment Neutral(0.998596727848053% =>Pollution & Waste)
# Two registred SOx non-com belongs to Environmental(0.9881608486175537%) with a sentiment Neutral(0.9976220726966858% =>Climate Change)
# Collaborative project des belongs to Social(0.9821385145187378%) with a sentiment Neutral(0.999996542930603% =>Natural Capital)
# Other opportunities explo belongs to Social(0.9855009913444519%) with a sentiment Neutral(0.8553781509399414% =>Community Relations)
# Well-functioning tax syst belongs to Social(0.9785770177841187%) with a sentiment Positive(0.9999998807907104% =>Community Relations)
# More severe weather event belongs to Environmental(0.9799946546554565%) with a sentiment Negative(0.975892186164856% =>Climate Change)
# Non-compliance with legis belongs to Governance(0.8683255314826965%) with a sentiment Negative(0.9998239874839783% =>Business Ethics & Values)
# We recognise the need for belongs to Social(0.9002879858016968%) with a sentiment Neutral(0.9999572038650513% =>Community Relations)
# To keep global warming be belongs to Environmental(0.9908825755119324%) with a sentiment Neutral(0.966575026512146% =>Climate Change)
# Our
# experience and insig belongs to Social(0.897659182548523%) with a sentiment Positive(0.9997463822364807% =>Natural Capital)
# We have a responsibility  belongs to Social(0.8353227972984314%) with a sentiment Neutral(0.8946375250816345% =>Business Ethics & Values)
# Lack of transparency on t belongs to None(0.6461846232414246%) with a sentiment Negative(0.999958872795105% =>Business Ethics & Values)
# Ocean transport contribut belongs to Environmental(0.9919819235801697%) with a sentiment Neutral(0.9980083107948303% =>Climate Change)
# As a market leader, we mu belongs to Environmental(0.9927531480789185%) with a sentiment Neutral(0.9722798466682434% =>Climate Change)
# Inadequate CO2 regulation belongs to Environmental(0.983730137348175%) with a sentiment Negative(0.9999974966049194% =>Climate Change)
# Climate change
# effects c belongs to Environmental(0.9329556226730347%) with a sentiment Negative(0.9331820607185364% =>Climate Change)
# Our work to combat all fo belongs to Governance(0.9252127408981323%) with a sentiment Neutral(0.9983915686607361% =>Business Ethics & Values)
# Our approach to tax is di belongs to None(0.9454194903373718%) with a sentiment Neutral(0.9999958276748657% =>Non-ESG)
# Moller - Maersk Tax
# Prin belongs to Governance(0.5597856640815735%) with a sentiment Neutral(0.9999582767486572% =>Corporate Governance)
# Our regulatory work on cl belongs to Environmental(0.986954391002655%) with a sentiment Neutral(0.9999932050704956% =>Climate Change)
# A dedicated project
# boar belongs to Social(0.8773618340492249%) with a sentiment Neutral(0.9999997615814209% =>Corporate Governance)
# Operationally, our work t belongs to Environmental(0.9935239553451538%) with a sentiment Neutral(0.9989582300186157% =>Climate Change)
# We want to be seen as lea belongs to Social(0.9387565851211548%) with a sentiment Positive(0.530147135257721% =>Business Ethics & Values)
# Be recognised by tax admi belongs to None(0.4142988920211792%) with a sentiment Neutral(0.9999837875366211% =>Corporate Governance)
# Be recognised by investor belongs to Governance(0.8430325388908386%) with a sentiment Neutral(0.9875553250312805% =>Corporate Governance)
# To help decarbonise logis belongs to Environmental(0.989604115486145%) with a sentiment Positive(0.9999979734420776% =>Climate Change)
# Map climate change relate belongs to Environmental(0.9805008172988892%) with a sentiment Negative(0.9997058510780334% =>Climate Change)
# Moller - Maersk assets
# a belongs to Social(0.7556939125061035%) with a sentiment Neutral(0.9999850988388062% =>Product Liability)
# Continue to engage in dia belongs to Governance(0.8165916800498962%) with a sentiment Neutral(0.9997619986534119% =>Corporate Governance)
# Meet our commitment to im belongs to Governance(0.8067795634269714%) with a sentiment Positive(0.9810945987701416% =>Corporate Governance)
# 60% relative CO2 reductio belongs to Environmental(0.990746021270752%) with a sentiment Neutral(0.9995443224906921% =>Climate Change)
# Develop low-carbon offeri belongs to Environmental(0.989485502243042%) with a sentiment Positive(0.9990962743759155% =>Climate Change)
# Reduced Maersk Line facil belongs to Social(0.548142671585083%) with a sentiment Negative(0.9560750126838684% =>Non-ESG)
# The scope is Maersk Line- belongs to None(0.934752345085144%) with a sentiment Neutral(0.999998927116394% =>Climate Change)
# subbrands. belongs to None(0.9759646058082581%) with a sentiment Neutral(0.9994731545448303% =>Non-ESG)
# Initiated pilot scheme wi belongs to Social(0.9503923654556274%) with a sentiment Neutral(0.9999821186065674% =>Community Relations)
# Strengthened framework fo belongs to Governance(0.9306469559669495%) with a sentiment Positive(0.9999988079071045% =>Business Ethics & Values)
# Tax charge was USD 1,191  belongs to None(0.9937112331390381%) with a sentiment Neutral(0.9996399879455566% =>Non-ESG)
# Updated tax principles ma belongs to Governance(0.5919009447097778%) with a sentiment Neutral(0.9915930032730103% =>Corporate Governance)
# Participated as a foundin belongs to Governance(0.7349680662155151%) with a sentiment Neutral(0.9999401569366455% =>Corporate Governance)
# Reduced relative CO2 emis belongs to Environmental(0.993296205997467%) with a sentiment Neutral(0.6465468406677246% =>Climate Change)
# Reduced CO2 emissions per belongs to Environmental(0.993777871131897%) with a sentiment Positive(0.8742868304252625% =>Climate Change)
# Decision to expand scope  belongs to Environmental(0.9919740557670593%) with a sentiment Neutral(0.8866148591041565% =>Climate Change)
# 85% of ship recycling glo belongs to Environmental(0.9849137663841248%) with a sentiment Neutral(0.6102476119995117% =>Pollution & Waste)
# 30% of all food produced  belongs to Environmental(0.8690279722213745%) with a sentiment Neutral(0.9997910857200623% =>Pollution & Waste)
# Food loss
# also connects  belongs to Environmental(0.9728813171386719%) with a sentiment Negative(0.9992361068725586% =>Climate Change)
# Lowering barriers to trad belongs to Social(0.9707306623458862%) with a sentiment Positive(0.9999490976333618% =>Community Relations)
# As a trade and logistics  belongs to None(0.9255454540252686%) with a sentiment Neutral(0.9998660087585449% =>Non-ESG)
# Moller - Maersk benefits  belongs to Social(0.5730767846107483%) with a sentiment Positive(1.0% =>Community Relations)
# Improving the standards a belongs to Environmental(0.9732412695884705%) with a sentiment Positive(1.0% =>Pollution & Waste)
# Curbing food loss will pr belongs to Social(0.785580039024353%) with a sentiment Positive(0.9999998807907104% =>Community Relations)
# Our
# cold chain logistics belongs to None(0.9900278449058533%) with a sentiment Positive(1.0% =>Non-ESG)
# Shipping has the potentia belongs to Social(0.9820350408554077%) with a sentiment Positive(0.9999961853027344% =>Community Relations)
# Our expertise should be p belongs to Social(0.9901251792907715%) with a sentiment Neutral(0.7195905447006226% =>Human Capital)
# Lack of inclusion may res belongs to Social(0.7361842393875122%) with a sentiment Negative(0.9908624887466431% =>Business Ethics & Values)
# A.P. belongs to None(0.9518617391586304%) with a sentiment Neutral(0.9990792274475098% =>Non-ESG)
# Moller - Maersk is linked belongs to Environmental(0.9485102891921997%) with a sentiment Neutral(0.9997724890708923% =>Pollution & Waste)
# As such, our responsibili belongs to Governance(0.8839441537857056%) with a sentiment Neutral(0.9673065543174744% =>Business Ethics & Values)
# There will be an uneven p belongs to Environmental(0.9843811988830566%) with a sentiment Neutral(0.6772640943527222% =>Pollution & Waste)
# Reputational damage may
#  belongs to Governance(0.7586429715156555%) with a sentiment Negative(0.9999947547912598% =>Business Ethics & Values)
# Our market share of food  belongs to None(0.9312061071395874%) with a sentiment Neutral(0.9999755620956421% =>Pollution & Waste)
# This strongly connects us belongs to None(0.904428243637085%) with a sentiment Positive(0.9999141693115234% =>Non-ESG)
# Ambition is governed by t belongs to Social(0.7657350897789001%) with a sentiment Neutral(0.9999741315841675% =>Corporate Governance)
# A dedicated Project Board belongs to Social(0.8773618340492249%) with a sentiment Neutral(0.9999997615814209% =>Corporate Governance)
# A.P. belongs to None(0.9518617391586304%) with a sentiment Neutral(0.9990792274475098% =>Non-ESG)
# Moller - Maersk’s Respons belongs to Environmental(0.9807985424995422%) with a sentiment Neutral(0.9997203946113586% =>Pollution & Waste)
# The ship recycling
# proje belongs to Environmental(0.9769697189331055%) with a sentiment Neutral(0.9999970197677612% =>Pollution & Waste)
# Ambition is governed by t belongs to Social(0.7657350897789001%) with a sentiment Neutral(0.9999741315841675% =>Corporate Governance)
# The
# project will from 20 belongs to Social(0.8816090822219849%) with a sentiment Neutral(0.9999988079071045% =>Corporate Governance)
# Multiply the benefits of  belongs to Social(0.9176773428916931%) with a sentiment Neutral(0.5958079099655151% =>Business Ethics & Values)
# We aspire to be part of t belongs to Environmental(0.7262869477272034%) with a sentiment Positive(0.9999712705612183% =>Pollution & Waste)
# We will invest on the sca belongs to Social(0.9263049364089966%) with a sentiment Neutral(0.9999669790267944% =>Product Liability)
# We will provide dedicated belongs to Social(0.9692520499229431%) with a sentiment Neutral(0.9999792575836182% =>Community Relations)
# Continue to invest and wo belongs to Social(0.8057945370674133%) with a sentiment Neutral(0.999947190284729% =>Human Capital)
# In partnership with relev belongs to Social(0.9802438020706177%) with a sentiment Neutral(0.9999815225601196% =>Community Relations)
# Initiate the Ship Recycli belongs to Environmental(0.9325853586196899%) with a sentiment Neutral(0.9691340327262878% =>Pollution & Waste)
# Established joint venture belongs to None(0.9327133893966675%) with a sentiment Neutral(0.999839186668396% =>Non-ESG)
# Fromtu platform continuou belongs to Environmental(0.7230356335639954%) with a sentiment Positive(0.9999995231628418% =>Product Liability)
# Two tools launched on Con belongs to None(0.9563029408454895%) with a sentiment Neutral(0.9989709854125977% =>Non-ESG)
# Carried out two studies o belongs to Social(0.929450511932373%) with a sentiment Neutral(0.9999986886978149% =>Community Relations)
# Received third-party conf belongs to Environmental(0.9808605909347534%) with a sentiment Neutral(0.9990942478179932% =>Pollution & Waste)
# Initiated and launched th belongs to Environmental(0.9870128035545349%) with a sentiment Neutral(0.9957807064056396% =>Pollution & Waste)
# Completed a capacity stud belongs to Social(0.9860190153121948%) with a sentiment Neutral(0.9984253644943237% =>Community Relations)
# Diver died after being fo belongs to Environmental(0.5690726041793823%) with a sentiment Negative(0.6299019455909729% =>Pollution & Waste)
# Contractor Security guard belongs to Social(0.9564986824989319%) with a sentiment Neutral(0.9999818801879883% =>Pollution & Waste)
# Safety is not something
#  belongs to Social(0.9809175729751587%) with a sentiment Neutral(0.9950479865074158% =>Natural Capital)
# Safety is part
# of our he belongs to Social(0.981694757938385%) with a sentiment Positive(0.9999992847442627% =>Human Capital)
# We’re
# disappointed when  belongs to Social(0.6933044791221619%) with a sentiment Negative(0.9998225569725037% =>Business Ethics & Values)
# When we lose
# people, we  belongs to Social(0.9865890741348267%) with a sentiment Negative(0.9998725652694702% =>Community Relations)
#  belongs to Environmental(0.5634858012199402%) with a sentiment Neutral(0.9726656675338745% =>Human Capital)
# Going
# forward, my collea belongs to Social(0.9497649669647217%) with a sentiment Neutral(0.7842647433280945% =>Human Capital)
# CLAUS HEMMINGSEN
# Vice CE belongs to Social(0.7499908208847046%) with a sentiment Neutral(0.999910831451416% =>Corporate Governance)
# Moller - Maersk Competenc belongs to Social(0.9484201073646545%) with a sentiment Neutral(0.9999990463256836% =>Human Capital)
# Svitzer also has in-house belongs to Social(0.9710788130760193%) with a sentiment Neutral(0.9999951124191284% =>Human Capital)
#  belongs to Social(0.5561162233352661%) with a sentiment Positive(0.9999998807907104% =>Human Capital)
# Audit
# results are entere belongs to Social(0.3658871054649353%) with a sentiment Neutral(0.9999382495880127% =>Corporate Governance)
# The result is quicker and belongs to Social(0.8276246190071106%) with a sentiment Positive(0.9999986886978149% =>Human Capital)
# LTIf is lost-time injury  belongs to Social(0.9395342469215393%) with a sentiment Neutral(0.9938312768936157% =>Human Capital)
# The figures above are bas belongs to Social(0.9637313485145569%) with a sentiment Neutral(0.9999983310699463% =>Human Capital)
# 1 Maersk Line LTIf for se belongs to Social(0.8360147476196289%) with a sentiment Neutral(0.9999518394470215% =>Natural Capital)
# Besides promoting a stron belongs to Social(0.9664865136146545%) with a sentiment Positive(0.9990155696868896% =>Human Capital)
# I give feedback on safety belongs to Social(0.9869707822799683%) with a sentiment Positive(0.9869013428688049% =>Human Capital)
# I can proudly say that
# t belongs to Social(0.9853743314743042%) with a sentiment Positive(0.9999998807907104% =>Human Capital)
# A MES NG
# HSEQ Officer, M belongs to Social(0.97340989112854%) with a sentiment Neutral(0.5501790642738342% =>Human Capital)
# Our progress on these fiv belongs to Social(0.8008574843406677%) with a sentiment Neutral(0.998469889163971% =>Non-ESG)
# Assets under
# constructio belongs to Social(0.9893830418586731%) with a sentiment Neutral(0.9999703168869019% =>Human Capital)
# In 2017, we published our belongs to Environmental(0.8536247611045837%) with a sentiment Neutral(0.9998631477355957% =>Product Liability)
# Training was conducted as belongs to Social(0.9688725471496582%) with a sentiment Neutral(0.9999905824661255% =>Human Capital)
# We comply stringently wit belongs to Social(0.9810243844985962%) with a sentiment Neutral(0.7848623394966125% =>Human Capital)
# Investigations of our opt belongs to Social(0.8226062655448914%) with a sentiment Neutral(0.9999005794525146% =>Pollution & Waste)
# We have developed a new f belongs to Social(0.9856342673301697%) with a sentiment Neutral(0.9997671246528625% =>Community Relations)
# The framework is based on belongs to Social(0.9780371785163879%) with a sentiment Neutral(0.9999923706054688% =>Human Capital)
# With the divestment of Ma belongs to None(0.6978946924209595%) with a sentiment Neutral(0.9516317248344421% =>Non-ESG)
# I’d like everyone
# commit belongs to Social(0.9880021810531616%) with a sentiment Neutral(0.530817985534668% =>Human Capital)
# This is
# not just a ‘fema belongs to Social(0.9849961996078491%) with a sentiment Negative(0.742900550365448% =>Human Capital)
# We must hold each
# other  belongs to Social(0.9113898277282715%) with a sentiment Neutral(0.9994845390319824% =>Business Ethics & Values)
# TARGETS AND PERFORMANCE O belongs to Social(0.9885224103927612%) with a sentiment Neutral(0.9879507422447205% =>Corporate Governance)
# Rather, an organisation i belongs to Social(0.9808881878852844%) with a sentiment Neutral(0.9999570846557617% =>Human Capital)
# 2 Performance for continu belongs to None(0.9946165680885315%) with a sentiment Neutral(0.9999572038650513% =>Non-ESG)
# See table on pages 46–47. belongs to None(0.9956666231155396%) with a sentiment Neutral(0.9999895095825195% =>Non-ESG)
# Progress in 2017
# Our act belongs to Social(0.9351560473442078%) with a sentiment Positive(0.9736190438270569% =>Corporate Governance)
# This is a result of the c belongs to Social(0.9537540078163147%) with a sentiment Neutral(0.9984575510025024% =>Corporate Governance)
# Our main To support our
#  belongs to Social(0.7944472432136536%) with a sentiment Positive(0.5501649975776672% =>Human Capital)
# We must accelerate
# progr belongs to Social(0.9729483723640442%) with a sentiment Negative(0.9785981774330139% =>Human Capital)
# PROCESS AND PERFORMANCE 2 belongs to None(0.9901930093765259%) with a sentiment Neutral(0.9999887943267822% =>Non-ESG)
# Shipbuilding yards
# Audit belongs to None(0.8476956486701965%) with a sentiment Neutral(0.9999843835830688% =>Corporate Governance)
# For 2017, trucking compan belongs to None(0.9704350829124451%) with a sentiment Neutral(0.9999923706054688% =>Non-ESG)
# ** The number of improvem belongs to None(0.9877519607543945%) with a sentiment Neutral(0.999936580657959% =>Non-ESG)
# 4. belongs to None(0.9485049247741699%) with a sentiment Neutral(0.9957857728004456% =>Non-ESG)
# Outsourced labour
# 5. belongs to Social(0.8540655374526978%) with a sentiment Neutral(0.9993492960929871% =>Human Capital)
# Terminals
# 6. belongs to None(0.9304543733596802%) with a sentiment Neutral(0.9644947052001953% =>Non-ESG)
# Shipbuilding yards / Dryd belongs to None(0.879931628704071%) with a sentiment Neutral(0.9999568462371826% =>Non-ESG)
# 8. belongs to None(0.976787269115448%) with a sentiment Neutral(0.9845485687255859% =>Non-ESG)
# Promotional items
# 9. belongs to None(0.9847286343574524%) with a sentiment Neutral(0.9928994178771973% =>Non-ESG)
# Custom agents
# 10. belongs to None(0.7775300741195679%) with a sentiment Neutral(0.9976232647895813% =>Non-ESG)
# Security onshore
# 11. belongs to Social(0.8757451772689819%) with a sentiment Neutral(0.9979990124702454% =>Product Liability)
# Construction
# 12. belongs to None(0.9554843306541443%) with a sentiment Neutral(0.9999586343765259% =>Non-ESG)
# Chemicals / Paints
# 13. belongs to None(0.910556972026825%) with a sentiment Neutral(0.9993564486503601% =>Non-ESG)
# Equipment / Maintenance / belongs to Social(0.987423837184906%) with a sentiment Negative(0.9994339346885681% =>Human Capital)
# We insist that our suppli belongs to Social(0.9666740298271179%) with a sentiment Neutral(0.9998462200164795% =>Business Ethics & Values)
# During 2016, we became aw belongs to Social(0.9866683483123779%) with a sentiment Neutral(0.9609755277633667% =>Human Capital)
# We have engaged the suppl belongs to Social(0.9852821826934814%) with a sentiment Neutral(0.9999173879623413% =>Human Capital)
# Training of Maersk’s mann belongs to Social(0.9762404561042786%) with a sentiment Neutral(0.999658465385437% =>Human Capital)
# No non-contained spills a belongs to None(0.9442887306213379%) with a sentiment Neutral(0.9999622106552124% =>Pollution & Waste)
# Keeping harmful substance belongs to Environmental(0.9590667486190796%) with a sentiment Negative(0.9999762773513794% =>Pollution & Waste)
# The risk of spills is man belongs to Environmental(0.8352788090705872%) with a sentiment Neutral(0.9868848323822021% =>Pollution & Waste)
# Training is carried out f belongs to Environmental(0.9801210165023804%) with a sentiment Neutral(0.9999924898147583% =>Pollution & Waste)
# al, Environ. belongs to None(0.9315136075019836%) with a sentiment Neutral(0.9983097314834595% =>Non-ESG)
# Sci. belongs to None(0.9303147196769714%) with a sentiment Neutral(0.9983708262443542% =>Non-ESG)
# Technol., 2009 As we inte belongs to Social(0.9727610945701599%) with a sentiment Neutral(0.999998927116394% =>Human Capital)
# Going forward,
# I see us  belongs to Social(0.9271512031555176%) with a sentiment Positive(0.6905665993690491% =>Business Ethics & Values)
# K EVIN FURNISS
# VP of HSS belongs to Social(0.8624721765518188%) with a sentiment Neutral(0.9999783039093018% =>Human Capital)
# Moller - Maersk ENGAGING  belongs to Social(0.9647042751312256%) with a sentiment Neutral(0.9996316432952881% =>Natural Capital)
# We not only use the ocean belongs to Social(0.9713155031204224%) with a sentiment Neutral(0.9991525411605835% =>Natural Capital)
# Our vessels emit CO2, whi belongs to Environmental(0.9850738048553467%) with a sentiment Negative(0.77667236328125% =>Climate Change)
# The long-term solution to belongs to Social(0.5167877674102783%) with a sentiment Neutral(0.9996440410614014% =>Natural Capital)
# 2 The Baltic Sea, the Nor belongs to Environmental(0.7793072462081909%) with a sentiment Positive(0.9995307922363281% =>Natural Capital)
# We will only
# succeed in  belongs to Social(0.9021027088165283%) with a sentiment Negative(0.9951004385948181% =>Business Ethics & Values)
# A.P. belongs to None(0.9518617391586304%) with a sentiment Neutral(0.9990792274475098% =>Non-ESG)
# Moller Maersk’s leadershi belongs to Social(0.9910844564437866%) with a sentiment Positive(0.9982232451438904% =>Human Capital)
# CECILIA MÜLLER TORBRAND
#  belongs to Governance(0.9225958585739136%) with a sentiment Positive(0.999789297580719% =>Business Ethics & Values)
# The ambassadors take on a belongs to Governance(0.9413502216339111%) with a sentiment Neutral(0.9999955892562866% =>Corporate Governance)
# To better integrate compl belongs to Social(0.8044690489768982%) with a sentiment Positive(0.9751906991004944% =>Business Ethics & Values)
# 1 Non-genuine whistleblow belongs to Governance(0.8362910151481628%) with a sentiment Neutral(0.9998058676719666% =>Business Ethics & Values)
# n 2017, A.P. belongs to None(0.9688376188278198%) with a sentiment Neutral(0.9993994235992432% =>Non-ESG)
# Moller - Maersk’s total t belongs to None(0.9875816106796265%) with a sentiment Neutral(0.9999778270721436% =>Non-ESG)
# Due to the separation of  belongs to None(0.9936822652816772%) with a sentiment Neutral(0.985551118850708% =>Non-ESG)
# • Our name: We acknowledg belongs to None(0.9082766771316528%) with a sentiment Neutral(0.9995343685150146% =>Corporate Governance)
# We wish to be
# associated belongs to Social(0.8086873292922974%) with a sentiment Neutral(0.9939965009689331% =>Business Ethics & Values)
# The updated tax principle belongs to None(0.8184670805931091%) with a sentiment Neutral(0.9999902248382568% =>Corporate Governance)
# The tax charge is the tot belongs to None(0.9954110980033875%) with a sentiment Neutral(0.9903613328933716% =>Non-ESG)
# See our Annual Report for belongs to None(0.9833160042762756%) with a sentiment Neutral(0.9993508458137512% =>Non-ESG)
# 3. belongs to None(0.9665738940238953%) with a sentiment Neutral(0.9915655851364136% =>Non-ESG)
# Value Creation for Shareh belongs to Governance(0.5227274894714355%) with a sentiment Positive(0.9999992847442627% =>Corporate Governance)
# … benefit from tax incent belongs to Social(0.8623659610748291%) with a sentiment Positive(0.6565336585044861% =>Community Relations)
# Foremost
# was the fact th belongs to Social(0.7567230463027954%) with a sentiment Neutral(0.8461877703666687% =>Community Relations)
# Moller - Maersk Builds on belongs to Environmental(0.5284270644187927%) with a sentiment Neutral(0.9371971487998962% =>Human Capital)
# Moller - Maersk
# represen belongs to Social(0.9884083867073059%) with a sentiment Neutral(0.999119222164154% =>Human Capital)
# finding in external audit belongs to Governance(0.8634927272796631%) with a sentiment Neutral(0.9999585151672363% =>Corporate Governance)
# (Related to
# excessive mo belongs to Social(0.9752046465873718%) with a sentiment Negative(0.9786888957023621% =>Human Capital)
# lost-time injury registre belongs to Social(0.7825711369514465%) with a sentiment Negative(0.998668909072876% =>Human Capital)
# of housing facilities com belongs to Social(0.9829941987991333%) with a sentiment Neutral(0.9984729886054993% =>Community Relations)
# of workers have contracts belongs to Social(0.9659915566444397%) with a sentiment Neutral(0.9999549388885498% =>Human Capital)
# Shree Ram plot V7 audit s belongs to Governance(0.5401834845542908%) with a sentiment Neutral(0.9999885559082031% =>Corporate Governance)
# of findings)
# Y.S. belongs to Social(0.7328135967254639%) with a sentiment Neutral(0.9985392093658447% =>Business Ethics & Values)
# Investments plot 59 audit belongs to Governance(0.8292579650878906%) with a sentiment Neutral(0.9999265670776367% =>Corporate Governance)
# of findings) Copenhagen,  belongs to Social(0.47439977526664734%) with a sentiment Neutral(0.9999032020568848% =>Climate Change)
# Please send your feedback belongs to None(0.9261783957481384%) with a sentiment Neutral(0.9996663331985474% =>Non-ESG)
# Møller - Mærsk A/S
# Espla belongs to Social(0.8146843910217285%) with a sentiment Neutral(0.9999697208404541% =>Climate Change)
# +45 33 63 33 63
# Company  belongs to None(0.8463293313980103%) with a sentiment Neutral(0.9995929598808289% =>Non-ESG)
# no. belongs to None(0.9460296630859375%) with a sentiment Neutral(0.977229654788971% =>Non-ESG)
# 22756214
# www.maersk.com belongs to None(0.9309433698654175%) with a sentiment Neutral(0.9994798302650452% =>Non-ESG)

# %%
df_csv = pd.DataFrame(dataset_lst)

# %%
df_csv
# Out:
#                                               sentence    topic_label  \
# 0    Companies can no longer stay on the\r\nsidelin...         Social
# 1                                 Our business\r\nA.P.           None
# 2    Moller - Maersk employs over 85,000\r\npeople ...         Social
# 3    Our vision is to be the global integrator of\r...         Social
# 4    Examples of where some of our material\r\nissu...  Environmental
# ..                                                 ...            ...
# 360              Please send your feedback to:\r\nA.P.           None
# 361  Møller - Mærsk A/S\r\nEsplanaden 50\r\nDK–1098...         Social
# 362                    +45 33 63 33 63\r\nCompany reg.           None
# 363                                                no.           None
# 364                         22756214\r\nwww.maersk.com           None
#
#      topic_score sentiment_label  sentiment_score         fls_label  \
# 0       0.957391         Neutral         0.992349  Non-specific FLS
# 1       0.976701         Neutral         0.998411           Not FLS
# 2       0.982447         Neutral         0.999999           Not FLS
# 3       0.954864        Positive         0.931021           Not FLS
# 4       0.760369         Neutral         0.975150           Not FLS
# ..           ...             ...              ...               ...
# 360     0.926178         Neutral         0.999666           Not FLS
# 361     0.814684         Neutral         0.999970           Not FLS
# 362     0.846329         Neutral         0.999593           Not FLS
# 363     0.946030         Neutral         0.977230           Not FLS
# 364     0.930943         Neutral         0.999480           Not FLS
#
#      fls_score      sub_cat_label  sub_cat_score
# 0     0.510004            Non-ESG       0.401613
# 1     0.990726            Non-ESG       0.784374
# 2     0.982055      Human Capital       0.828750
# 3     0.946253  Product Liability       0.499080
# 4     0.978589  Pollution & Waste       0.637766
# ..         ...                ...            ...
# 360   0.878980            Non-ESG       0.544031
# 361   0.970404     Climate Change       0.347196
# 362   0.981492            Non-ESG       0.797524
# 363   0.919827            Non-ESG       0.932540
# 364   0.966812            Non-ESG       0.598518
#
# [365 rows x 9 columns]

# %%
df_csv.to_csv('Data/labeled_sentences_positive_G_365_extra_classes.csv')
