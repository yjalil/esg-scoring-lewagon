# %% [markdown]
# # Getting news
# Let's assume the user picked Apple in a dropdown on our user interface. We will have a collection of csv files from the GDELT project downloaded. Each csv represents a day from 1979 to present. The example we will use in this notebook is a list of all news on 15 October 2015.

# %%
import pandas as pd

# %%
# Loding the csv (tab seperator)
df_articles = pd.read_csv('data/20221015.export.CSV',sep='\t', header=None)
# Out:
# C:\Users\ylila\AppData\Local\Temp\ipykernel_12620\1412090400.py:2: DtypeWarning: Columns (11,14,21,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_articles = pd.read_csv('data/20221015.export.CSV',sep='\t', header=None)

# %%
list_columns = 'GLOBALEVENTID	SQLDATE	MonthYear	Year	FractionDate	Actor1Code	Actor1Name	Actor1CountryCode	Actor1KnownGroupCode	Actor1EthnicCode	Actor1Religion1Code	Actor1Religion2Code	Actor1Type1Code	Actor1Type2Code	Actor1Type3Code	Actor2Code	Actor2Name	Actor2CountryCode	Actor2KnownGroupCode	Actor2EthnicCode	Actor2Religion1Code	Actor2Religion2Code	Actor2Type1Code	Actor2Type2Code	Actor2Type3Code	IsRootEvent	EventCode	EventBaseCode	EventRootCode	QuadClass	GoldsteinScale	NumMentions	NumSources	NumArticles	AvgTone	Actor1Geo_Type	Actor1Geo_FullName	Actor1Geo_CountryCode	Actor1Geo_ADM1Code	Actor1Geo_Lat	Actor1Geo_Long	Actor1Geo_FeatureID	Actor2Geo_Type	Actor2Geo_FullName	Actor2Geo_CountryCode	Actor2Geo_ADM1Code	Actor2Geo_Lat	Actor2Geo_Long	Actor2Geo_FeatureID	ActionGeo_Type	ActionGeo_FullName	ActionGeo_CountryCode	ActionGeo_ADM1Code	ActionGeo_Lat	ActionGeo_Long	ActionGeo_FeatureID	DATEADDED	SOURCEURL'
df_articles.columns = list_columns.split('\t')
df_articles.head(5)
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0     1067644303  20211015     202110  2021     2021.7808        NaN
# 1     1067644304  20211015     202110  2021     2021.7808        AUS
# 2     1067644305  20211015     202110  2021     2021.7808        AUS
# 3     1067644306  20211015     202110  2021     2021.7808        IRQ
# 4     1067644307  20211015     202110  2021     2021.7808        IRQ
#
#    Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  ...  \
# 0         NaN               NaN                  NaN              NaN  ...
# 1  AUSTRALIAN               AUS                  NaN              NaN  ...
# 2  AUSTRALIAN               AUS                  NaN              NaN  ...
# 3        IRAQ               IRQ                  NaN              NaN  ...
# 4        IRAQ               IRQ                  NaN              NaN  ...
#
#   Actor2Geo_FeatureID ActionGeo_Type                     ActionGeo_FullName  \
# ...

# %%
df_articles = df_articles[['GLOBALEVENTID','SQLDATE','MonthYear','Year','FractionDate','Actor1Code','Actor1Name','Actor1Type1Code','Actor1Type2Code','Actor1Type3Code','Actor2Code','Actor2Name','Actor2Type1Code','SOURCEURL']]
df_articles.iloc[2333,:]
# Out:
# GLOBALEVENTID                                             1067646636
# SQLDATE                                                     20221015
# MonthYear                                                     202210
# Year                                                            2022
# FractionDate                                               2022.7808
# Actor1Code                                                       BUS
# Actor1Name                                                   COMPANY
# Actor1Type1Code                                                  BUS
# Actor1Type2Code                                                  NaN
# Actor1Type3Code                                                  NaN
# Actor2Code                                                       NaN
# Actor2Name                                                       NaN
# Actor2Type1Code                                                  NaN
# SOURCEURL          https://www.forbes.com/sites/ewanspence/2022/1...
# ...

# %%
# Find apple in the URL title, we'll probably switch to a better way to filter. GDELT always name the actor COMPANY, we must assume we won't always be lucky enough to find the name in the URL.
df_apple = df_articles[df_articles['SOURCEURL'].str.contains("apple")].copy()
df_apple.head(10)
# Out:
#        GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 2333      1067646636  20221015     202210  2022     2022.7808        BUS
# 8790      1067656060  20221015     202210  2022     2022.7808        BUS
# 9089      1067656359  20221015     202210  2022     2022.7808        LAB
# 9099      1067656369  20221015     202210  2022     2022.7808        LAB
# 9432      1067656702  20221015     202210  2022     2022.7808        USA
# 9971      1067657575  20221015     202210  2022     2022.7808        LAB
# 9973      1067657577  20221015     202210  2022     2022.7808        LAB
# 9974      1067657578  20221015     202210  2022     2022.7808        LAB
# 10828     1067659047  20220915     202209  2022     2022.6986        USA
# 10897     1067659116  20221015     202210  2022     2022.7808        NaN
#
#           Actor1Name Actor1Type1Code Actor1Type2Code Actor1Type3Code  \
# 2333         COMPANY             BUS             NaN             NaN
# ...

# %% [markdown]
# We found 78 articles about apple for one day. Let's save the URLs in a csv for the next Notebook.

# %%
df_apple['SOURCEURL'].to_csv('Data/apple_news_20221015.csv')
